# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'outputs/initial_soc_charging_sensitivity/combined_summary.csv')
data
# Out:
#     configured_initial_battery_mean  realized_initial_battery_mean  \
# 0                             0.875                       0.873609
# 1                             0.875                       0.873609
# 2                             0.875                       0.873609
# 3                             0.875                       0.873609
# 4                             0.875                       0.873609
# 5                             0.875                       0.873609
# 6                             0.875                       0.873609
# 7                             0.450                       0.448609
# 8                             0.450                       0.448609
# 9                             0.450                       0.448609
# 10                            0.450                       0.448609
# 11                            0.450                       0.448609
# 12                            0.450                       0.448609
# ...

# %%
data = pd.read_csv(r'outputs/initial_soc_charging_sensitivity/combined_summary.csv')
label_map = {
     0.875: 'H',
    0.450: "M",
    0.150:"L"
}
data['configured_initial_battery_mean'] = data['configured_initial_battery_mean'].map(label_map)
columns = ['configured_initial_battery_mean', ]
# Out:
#    configured_initial_battery_mean  realized_initial_battery_mean  \
# 0                                H                       0.873609
# 1                                H                       0.873609
# 2                                H                       0.873609
# 3                                H                       0.873609
# 4                                H                       0.873609
# 5                                H                       0.873609
# 6                                H                       0.873609
# 7                                M                       0.448609
# 8                                M                       0.448609
# 9                                M                       0.448609
# 10                               M                       0.448609
# 11                               M                       0.448609
# 12                               M                       0.448609
# ...

# %%
data['avg_daily_charging_sessions_per_human_ev']
# Out:
# 0     5.716667
# 1     5.470000
# 2     5.626667
# 3     5.676667
# 4     5.780000
# 5     5.913333
# 6     5.820000
# 7     5.740000
# 8     5.786667
# 9     5.450000
# 10    5.630000
# 11    5.630000
# 12    5.666667
# 13    5.573333
# 14    1.113333
# 15    1.083333
# 16    0.990000
# 17    1.130000
# 18    1.013333
# 19    1.096667
# 20    0.990000
# Name: avg_daily_charging_sessions_per_human_ev, dtype: float64

# %%
data['avg_daily_charging_sessions_per_aev']
# Out:
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     0.000000
# 4     0.000000
# 5     0.000000
# 6     0.000000
# 7     0.000000
# 8     0.000000
# 9     0.000000
# 10    0.000000
# 11    0.000000
# 12    0.000000
# 13    0.000000
# 14    0.686667
# 15    0.670000
# 16    0.680000
# 17    0.673333
# 18    0.670000
# 19    0.670000
# 20    0.683333
# Name: avg_daily_charging_sessions_per_aev, dtype: float64

# %%
data
# Out:
#     configured_initial_battery_mean  realized_initial_battery_mean  \
# 0                             0.875                       0.873609
# 1                             0.875                       0.873609
# 2                             0.875                       0.873609
# 3                             0.875                       0.873609
# 4                             0.875                       0.873609
# 5                             0.875                       0.873609
# 6                             0.875                       0.873609
# 7                             0.450                       0.448609
# 8                             0.450                       0.448609
# 9                             0.450                       0.448609
# 10                            0.450                       0.448609
# 11                            0.450                       0.448609
# 12                            0.450                       0.448609
# ...
